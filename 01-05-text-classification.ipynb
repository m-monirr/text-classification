# %% [markdown]
# # Text Classification
#
# This is our `hello world` example

# %%
# a helper functions and imports
from IPython.display import display
def highlight_col(x, df):
    #set by condition
    mask =  df['label'] == 'pos'
    mask2 = df['label'] == 'neg'
    x = pd.DataFrame('', index=df.index, columns=df.columns)
    x.loc[mask] = 'background-color: #e6ffe6'
    x.loc[mask2] = 'background-color: #ffe6e6'
    return x

# %% [markdown]
# ## Load the data

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

train_pos = pd.read_csv("train_Arabic_tweets_positive_20190413.tsv", sep='\t', header=None)
train_neg = pd.read_csv("train_Arabic_tweets_negative_20190413.tsv", sep='\t', header=None)
train_data = pd.concat([train_pos, train_neg], ignore_index=True)
train_data.columns = ['label', 'tweet']
del train_pos, train_neg

pd.set_option('display.max_colwidth', 100000)
df_tmp = train_data.sample(5)
df_tmp.style.apply(lambda x: highlight_col(x, df_tmp), axis=None)
# Out:
# <style type="text/css">
# #T_fb415_row0_col0, #T_fb415_row0_col1, #T_fb415_row1_col0, #T_fb415_row1_col1, #T_fb415_row2_col0, #T_fb415_row2_col1, #T_fb415_row3_col0, #T_fb415_row3_col1 {
#   background-color: #ffe6e6;
# }
# #T_fb415_row4_col0, #T_fb415_row4_col1 {
#   background-color: #e6ffe6;
# }
# </style>
# <table id="T_fb415">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb415_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_fb415_level0_col1" class="col_heading level0 col1" >tweet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb415_level0_row0" class="row_heading level0 row0" >33192</th>
#       <td id="T_fb415_row0_col0" class="data row0 col0" >neg</td>
#       <td id="T_fb415_row0_col1" class="data row0 col1" >رحم الله امرء عرف مقدار نفسه 🤣🤣 تعجبني 👍🏻</td>
#     </tr>
#     <tr>
#       <th id="T_fb415_level0_row1" class="row_heading level0 row1" >27768</th>
#       <td id="T_fb415_row1_col0" class="data row1 col0" >neg</td>
#       <td id="T_fb415_row1_col1" class="data row1 col1" >ليتك تفرحنا وتحكيلنا قصة ليمان وكيف كان يأمر الأتراك بأن يضعوا أهلك على الخوازيق وكان الترك ينفذون أوامره وليتك تحك…</td>
#     </tr>
#     <tr>
#       <th id="T_fb415_level0_row2" class="row_heading level0 row2" >43112</th>
#       <td id="T_fb415_row2_col0" class="data row2 col0" >neg</td>
#       <td id="T_fb415_row2_col1" class="data row2 col1" >افا هذي اخرتها نردد نشيد #الاتحاد ؟ طول عمرنا نهايط ونقول #الهلال مايهمه أحد وفوق الجميع والحين ندور الفزعة من فريق…</td>
#     </tr>
#     <tr>
#       <th id="T_fb415_level0_row3" class="row_heading level0 row3" >26694</th>
#       <td id="T_fb415_row3_col0" class="data row3 col0" >neg</td>
#       <td id="T_fb415_row3_col1" class="data row3 col1" >صراحه ماكنت ناويه احط لايك يوم شفتك تهددين خفت وحطيت يعني اللايك اجباري 💔</td>
#     </tr>
#     <tr>
#       <th id="T_fb415_level0_row4" class="row_heading level0 row4" >17026</th>
#       <td id="T_fb415_row4_col0" class="data row4 col0" >pos</td>
#       <td id="T_fb415_row4_col1" class="data row4 col1" >طفله سألت جدها ؟ هل لديك اسنان ياجدي 😎 قال لا فقالت الطفله الحمد الله 😂 هاك الزم التفاحه هسه اجي 😂😯 يمه البنات 😍</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_pos = pd.read_csv("test_Arabic_tweets_positive_20190413.tsv", sep='\t', header=None)
test_neg = pd.read_csv("test_Arabic_tweets_negative_20190413.tsv", sep='\t', header=None)
test_data = pd.concat([test_pos, test_neg], ignore_index=True)
test_data.columns = ['label', 'tweet']
del test_pos, test_neg

df_tmp = test_data.sample(5)
df_tmp.style.apply(lambda x: highlight_col(x, df_tmp), axis=None)
# Out:
# <style type="text/css">
# #T_54a9d_row0_col0, #T_54a9d_row0_col1, #T_54a9d_row1_col0, #T_54a9d_row1_col1, #T_54a9d_row4_col0, #T_54a9d_row4_col1 {
#   background-color: #ffe6e6;
# }
# #T_54a9d_row2_col0, #T_54a9d_row2_col1, #T_54a9d_row3_col0, #T_54a9d_row3_col1 {
#   background-color: #e6ffe6;
# }
# </style>
# <table id="T_54a9d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54a9d_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_54a9d_level0_col1" class="col_heading level0 col1" >tweet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54a9d_level0_row0" class="row_heading level0 row0" >8956</th>
#       <td id="T_54a9d_row0_col0" class="data row0 col0" >neg</td>
#       <td id="T_54a9d_row0_col1" class="data row0 col1" >جمهورنا : المتبعثر المكسور ! ياما : عطا .. ولا أخذ : حاجة ! ' ياما : وفا .. ولا عليه " قصور " ياما انجرح .. ولا لق…</td>
#     </tr>
#     <tr>
#       <th id="T_54a9d_level0_row1" class="row_heading level0 row1" >6983</th>
#       <td id="T_54a9d_row1_col0" class="data row1 col0" >neg</td>
#       <td id="T_54a9d_row1_col1" class="data row1 col1" >مين انتم 😐</td>
#     </tr>
#     <tr>
#       <th id="T_54a9d_level0_row2" class="row_heading level0 row2" >1749</th>
#       <td id="T_54a9d_row2_col0" class="data row2 col0" >pos</td>
#       <td id="T_54a9d_row2_col1" class="data row2 col1" >الي راح حمادة والي جاي حمادة تاني خالص. الناس الي طلعت واحتفلت دي عارفة أن الشغل الجد يادوب حيبدأ؟! اسقاط النظام ه…</td>
#     </tr>
#     <tr>
#       <th id="T_54a9d_level0_row3" class="row_heading level0 row3" >3995</th>
#       <td id="T_54a9d_row3_col0" class="data row3 col0" >pos</td>
#       <td id="T_54a9d_row3_col1" class="data row3 col1" >حسابات ملگية♛ 🌟🌟 مغردون مميزون.. لهم حضور أنيق وحروف رآقية 🌸 #حسابات_ملكية_تستحق_المتابعة 👇🏻👇🏻👇🏻👇🏻…</td>
#     </tr>
#     <tr>
#       <th id="T_54a9d_level0_row4" class="row_heading level0 row4" >6659</th>
#       <td id="T_54a9d_row4_col0" class="data row4 col0" >neg</td>
#       <td id="T_54a9d_row4_col1" class="data row4 col1" >عن نفسي انا ما شفت تويتات تشكيك في تجمع المهنيين او تخوينهم شفت تويتات ناس بتتكلم بس عن الناس الخونو 😕</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Baseline model (using pipeline)

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.pipeline import make_pipeline

vec = CountVectorizer()
clf = LogisticRegression()
pipe = make_pipeline(vec, clf)
pipe.fit(train_data.tweet, train_data.label);

# %% [markdown]
# Let's test this basic model

# %%
from sklearn import metrics

def print_report(pipe, x_test, y_test):
    y_pred = pipe.predict(x_test)
    report = metrics.classification_report(y_test, y_pred)
    print(report)
    print("accuracy: {:0.3f}".format(metrics.accuracy_score(y_test, y_pred)))

print_report(pipe, test_data.tweet, test_data.label)
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.77      0.82      0.80      5768
#          pos       0.81      0.76      0.78      5752
#
#     accuracy                           0.79     11520
#    macro avg       0.79      0.79      0.79     11520
# weighted avg       0.79      0.79      0.79     11520
#
# accuracy: 0.792

# %% [markdown]
# ## let's take a look inside the model

# %%
import eli5
eli5.show_weights(clf, vec=vec, top=20)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.783
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         الإخونج
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.393
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         وصباحك
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.214
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         هالسنه
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.25%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.160
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         السحب
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.63%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.091
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         برونو
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.67%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.082
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ابريل
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.70%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.077
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         الزرقاء
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.99%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.025
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         اللوك
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.73%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.893
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         الطيب
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.83%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.876
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         مبروك
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.91%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.862
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         حكمة
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.04%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.839
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ريهام
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 85.04%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 36164 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 85.35%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 34673 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 85.35%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.784
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         مناحل_ابو_سلطان
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 85.10%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.828
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         فاتني
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 85.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.840
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         خرووج
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 84.16%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.994
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         يستر
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 83.41%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.131
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         زعيم_تويتر_فولورز_اهلاوي
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 83.10%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.189
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         مسلسل_ودك_يتكرر_برمضان
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 82.81%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.243
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         أجباري_وليس_أختياري
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 81.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.551
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         امطار_الشرقيه
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>

# %% [markdown]
# ## Try our model on some tweets

# %%
for _, row in test_data.sample(5).iterrows():
    print(f"true label: {row['label']}")
    display(eli5.show_prediction(clf, row['tweet'], vec=vec,))
    print("--"*50)
# Out:
# true label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (probability <b>0.814</b>, score <b>-1.477</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.144
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.57%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.333
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:0; white-space: pre-wrap;"><span style="opacity: 0.80">r - تويتاتج ع </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.584">الجرح</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 78.82%); opacity: 0.88" title="0.236">والله</span><span style="opacity: 0.80"> ، </span><span style="background-color: hsl(120, 100.00%, 64.45%); opacity: 0.97" title="0.494">الافتار</span><span style="opacity: 0.80"> :( اسلووبج </span><span style="background-color: hsl(0, 100.00%, 86.79%); opacity: 0.84" title="-0.120">يهبل</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 92.89%); opacity: 0.82" title="-0.050">ياخ</span></p>
# ----------------------------------------------------------------------------------------------------
# true label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (probability <b>0.849</b>, score <b>-1.724</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.391
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.65%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.333
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:0; white-space: pre-wrap;"><span style="opacity: 0.80">ف </span><span style="background-color: hsl(120, 100.00%, 84.91%); opacity: 0.85" title="0.094">راق</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 87.19%); opacity: 0.84" title="0.074">العشاق</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.378">مش</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 77.93%); opacity: 0.89" title="0.162">بيقتل</span><span style="opacity: 0.80"> 😔 </span><span style="background-color: hsl(120, 100.00%, 69.46%); opacity: 0.94" title="0.257">وف</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 84.91%); opacity: 0.85" title="0.094">راق</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.71%); opacity: 0.81" title="-0.021">الحبيب</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.378">مش</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 80.44%); opacity: 0.87" title="-0.136">بيوجع</span><span style="opacity: 0.80"> 😔 </span><span style="background-color: hsl(120, 100.00%, 94.58%); opacity: 0.81" title="0.022">قد</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 73.14%); opacity: 0.91" title="0.214">فراق</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 81.55%); opacity: 0.87" title="-0.125">ميت</span><span style="opacity: 0.80"> ✋😭😭</span></p>
# ----------------------------------------------------------------------------------------------------
# true label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (probability <b>0.791</b>, score <b>-1.332</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.999
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.73%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.333
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:0; white-space: pre-wrap;"><span style="background-color: hsl(120, 100.00%, 81.90%); opacity: 0.86" title="0.243">تعالي</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.756">خااص</span><span style="opacity: 0.80"> 🤔</span></p>
# ----------------------------------------------------------------------------------------------------
# true label: pos
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (probability <b>0.758</b>, score <b>1.141</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.474
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 92.94%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.333
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:0; white-space: pre-wrap;"><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="1.474">صباحكم</span><span style="opacity: 0.80"> سكرووزز 💘</span></p>
# ----------------------------------------------------------------------------------------------------
# true label: pos
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (probability <b>0.976</b>, score <b>3.694</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.027
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 96.51%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.333
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:0; white-space: pre-wrap;"><span style="background-color: hsl(120, 100.00%, 92.39%); opacity: 0.82" title="0.099">على</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 85.53%); opacity: 0.85" title="-0.247">الفطرة</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 79.70%); opacity: 0.88" title="0.400">السليمه</span><span style="opacity: 0.80">.. </span><span style="background-color: hsl(120, 100.00%, 85.82%); opacity: 0.85" title="0.240">الله</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 81.17%); opacity: 0.87" title="0.359">يعطيه</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="1.054">الصحة</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 69.85%); opacity: 0.93" title="0.704">والعافية</span><span style="opacity: 0.80"> 😂 </span><span style="background-color: hsl(0, 100.00%, 88.62%); opacity: 0.83" title="-0.175">سكر</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 79.70%); opacity: 0.88" title="0.400">الطبلون</span><span style="opacity: 0.80"> .. </span><span style="background-color: hsl(120, 100.00%, 79.70%); opacity: 0.88" title="0.400">واللحق</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.39%); opacity: 0.82" title="0.099">على</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 83.76%); opacity: 0.86" title="0.291">الباب</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.34%); opacity: 0.80" title="0.003">لا</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 79.70%); opacity: 0.88" title="0.400">يقفله</span></p>
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Try Tfidf with some processing

# %%
vec = TfidfVectorizer(analyzer='char_wb', ngram_range=(3, 5), min_df=.01, max_df=.3)
clf = LinearSVC()
pipe_tfidf = make_pipeline(vec, clf)
pipe_tfidf.fit(train_data.tweet, train_data.label)
# Out:
# Pipeline(steps=[('tfidfvectorizer',
#                  TfidfVectorizer(analyzer='char_wb', max_df=0.3, min_df=0.01,
#                                  ngram_range=(3, 5))),
#                 ('linearsvc', LinearSVC())])

# %%
print_report(pipe_tfidf, test_data.tweet, test_data.label)
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.85      0.82      0.84      5768
#          pos       0.83      0.86      0.84      5752
#
#     accuracy                           0.84     11520
#    macro avg       0.84      0.84      0.84     11520
# weighted avg       0.84      0.84      0.84     11520
#
# accuracy: 0.838

# %%
eli5.show_weights(clf, vec=vec, top=20)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.43%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.905
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>😂<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.35%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.245
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>💙<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.222
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>💛<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.580
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>🌹<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.40%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.866
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>🤣<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.41%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.857
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>❤<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.61%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.727
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>😍<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.864
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         تويت<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.56%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.555
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>💪<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 93.56%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 772 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 93.45%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 741 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 93.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.618
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(0, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>😏<span style="background-color: hsl(0, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 92.51%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.174
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         :(<span style="background-color: hsl(0, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 92.51%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.174
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(0, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>:(<span style="background-color: hsl(0, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 92.28%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.313
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         لال<span style="background-color:

# %%
for _, row in test_data.sample(5).iterrows():
    print(f"true label: {row['label']}")
    display(eli5.show_prediction(clf, row['tweet'], vec=vec,))
    print("--"*50)
# Out:
# true label: pos
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (score <b>1.888</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.804
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 97.66%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.084
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:0; white-space: pre-wrap;"><span style="background-color: hsl(0, 100.00%, 92.74%); opacity: 0.82" title="-0.020">ا</span><span style="background-color: hsl(120, 100.00%, 89.45%); opacity: 0.83" title="0.034">ل</span><span style="background-color: hsl(120, 100.00%, 93.66%); opacity: 0.81" title="0.017">ح</span><span style="background-color: hsl(120, 100.00%, 96.83%); opacity: 0.81" title="0.006">م</span><span style="background-color: hsl(120, 100.00%, 94.57%); opacity: 0.81" title="0.013">د</span><span style="background-color: hsl(0, 100.00%, 98.45%); opacity: 0.80" title="-0.002"> </span><span style="background-color: hsl(120, 100.00%, 89.67%); opacity: 0.83" title="0.033">لل</span><span style="background-color: hsl(120, 100.00%, 89.38%); opacity: 0.83" title="0.035">ه</span><span style="opacity: 0.80">💙</span><span style="background-color: hsl(120, 100.00%, 95.68%); opacity: 0.81" title="0.010"> أ</span><span style="background-color: hsl(120, 100.00%, 83.18%); opacity: 0.86" title="0.067">ل</span><span style="background-color: hsl(120, 100.00%, 84.91%); opacity: 0.85" title="0.057">ف</span><span style="background-color: hsl(120, 100.00%, 83.15%); opacity: 0.86" title="0.067"> </span><span style="background-color: hsl(120, 100.00%, 90.74%); opacity: 0.82" title="0.028">م</span><span style="background-color: hsl(120, 100.00%, 87.71%); opacity: 0.84" title="0.043">ب</span><span style="background-color: hsl(120, 100.00%, 90.19%); opacity: 0.83" title="0.031">ر</span><span style="background-color: hsl(120, 100.00%, 84.22%); opacity: 0.85" title="0.061">و</span><span style="background-color: hsl(120, 100.00%, 90.86%); opacity: 0.82" title="0.028">ك</span><span style="background-color: hsl(120, 100.00%, 94.62%); opacity: 0.81" title="0.013"> </span><span style="background-color: hsl(0, 100.00%, 94.14%); opacity: 0.81" title="-0.015">يا</span><span style="opacity: 0.80">ز</span><span style="background-color: hsl(120, 100.00%, 90.28%); opacity: 0.83" title="0.030">ع</span><span style="background-color: hsl(120, 100.00%, 80.80%); opacity: 0.87" title="0.080">م</span><span style="background-color: hsl(120, 100.00%, 82.18%); opacity: 0.86" title="0.072">ا</span><span style="background-color: hsl(120, 100.00%, 87.85%); opacity: 0.84" title="0.042">ء</span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.230"> </span><span style="background-color: hsl(120, 100.00%, 63.58%); opacity: 0.97" title="0.201">💙</span><span style="background-color: hsl(120, 100.00%, 65.73%); opacity: 0.96" title="0.184"> </span><span style="background-color: hsl(120, 100.00%, 96.28%); opacity: 0.81" title="0.008">ا</span><span style="background-color: hsl(120, 100.00%, 90.06%); opacity: 0.83" title="0.031">ل</span><span style="background-color: hsl(120, 100.00%, 85.00%); opacity: 0.85" title="0.057">ق</span><span style="background-color: hsl(120, 100.00%, 93.52%); opacity: 0.81" title="0.017">ا</span><span style="background-color: hsl(120, 100.00%, 91.52%); opacity: 0.82" title="0.025">د</span><span style="background-color: hsl(0, 100.00%, 99.85%); opacity: 0.80" title="-0.000">م</span><span style="background-color: hsl(120, 100.00%, 90.12%); opacity: 0.83" title="0.031"> </span><span style="background-color: hsl(120, 100.00%, 97.85%); opacity: 0.80" title="0.004">أ</span><span style="background-color: hsl(120, 100.00%, 87.43%); opacity: 0.84" title="0.044">ج</span><span style="background-color: hsl(120, 100.00%, 81.47%); opacity: 0.87" title="0.076">مل</span><span style="background-color: hsl(0, 100.00%, 81.69%); opacity: 0.87" title="-0.075"> </span><span style="background-color: hsl(120, 100.00%, 92.17%); opacity: 0.82" title="0.022">إن</span><span style="background-color: hsl(120, 100.00%, 90.70%); opacity: 0.82" title="0.029"> </span><span style="background-color: hsl(120, 100.00%, 95.34%); opacity: 0.81" title="0.011">ش</span><span style="background-color: hsl(120, 100.00%, 98.32 ...
# ----------------------------------------------------------------------------------------------------
# true label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (score <b>0.775</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.690
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.41%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.084
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:0; white-space: pre-wrap;"><span style="background-color: hsl(0, 100.00%, 82.31%); opacity: 0.86" title="-0.047">ي</span><span style="background-color: hsl(120, 100.00%, 85.73%); opacity: 0.85" title="0.035">ا</span><span style="background-color: hsl(120, 100.00%, 80.51%); opacity: 0.87" title="0.054">ر</span><span style="background-color: hsl(120, 100.00%, 86.84%); opacity: 0.84" title="0.031">ب</span><span style="background-color: hsl(120, 100.00%, 62.17%); opacity: 0.98" title="0.140"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0
opacity: 0.83" title="0.029">ا</span><span style="background-color: hsl(120, 100.00%, 94.50%); opacity: 0.81" title="0.010">ل</span><span style="background-color: hsl(0, 100.00%, 81.68%); opacity: 0.87" title="-0.055"> </span><span style="background-color: hsl(120, 100.00%, 99.47%); opacity: 0.80" title="0.000">..</span><span style="background-color: hsl(120, 100.00%, 67.27%); opacity: 0.95" title="0.125"> </span><span style="background-color: hsl(120, 100.00%, 65.42%); opacity: 0.96" title="0.135">💙</span><span style="background-color: hsl(120, 100.00%, 71.52%); opacity: 0.92" title="0.102"> </span><span style="background-color: hsl(0, 100.00%, 84.42%); opacity: 0.85" title="-0.043">س</span><span style="background-color: hsl(0, 100.00%, 89.88%); opacity: 0.83" title="-0.023">ح</span><span style="background-color: hsl(120, 100.00%, 88.95%); opacity: 0.83" title="0.026">ب</span><span style="background-color: hsl(120, 100.00%, 95.05%); opacity: 0.81" title="0.008"> </span><span style="background-color: hsl(0, 100.00%, 96.90%); opacity: 0.81" title="-0.004">ع</span><span style="background-color: hsl(0, 100.00%, 98.90%); opacity: 0.80" title="-0.001">ل</span><span style="background-color: hsl(0, 100.00%, 91.41%); opacity: 0.82" title="-0.018">ى</span><span style="background-color: hsl(120, 100.00%, 95.46%); opacity: 0.81" title="0.007"> </span><span style="opacity: 0.80">آ</span><span style="background-color: hsl(120, 100.00%, 95.08%); opacity: 0.81" title="0.008">ي</span><span style="background-color: hsl(0, 100.00%, 94.05%); opacity: 0.81" title="-0.011">ف</span><span style="background-color: hsl(0, 100.00%, 95.08%); opacity: 0.81" title="-0.008">و</span><span style="background-color: hsl(120, 100.00%, 97.47%); opacity: 0.80" title="0.003">ن</span><span style="background-color: hsl(0, 100.00%, 76.67%); opacity: 0.89" title="-0.077"> </span><span style="opacity: 0.80">xr📱</span><span style="background-color: hsl(0, 100.00%, 87.66%); opacity: 0.84" title="-0.031"> </span><span style="background-color: hsl(0, 100.00%, 92.80%); opacity: 0.82" title="-0.014">ر</span><span style="background-color: hsl(120, 100.00%, 90.13%); opacity: 0.83" title="0.023">ت</span><span style="background-color: hsl(120, 100.00%, 95.51%); opacity: 0.81" title="0.007">و</span><span style="background-color: hsl(0, 100.00%, 94.25%); opacity: 0 ...
# ----------------------------------------------------------------------------------------------------
# true label: pos
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (score <b>2.087</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.003
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 97.82%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.084
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:0; white-space: pre-wrap;"><span style="background-color: hsl(0, 100.00%, 91.45%); opacity: 0.82" title="-0.097">كا</span><span style="opacity: 0.80">ر</span><span style="background-color: hsl(0, 100.00%, 94.49%); opacity: 0.81" title="-0.052">دي</span><span style="background-color: hsl(0, 100.00%, 95.96%); opacity: 0.81" title="-0.033"> </span><span style="background-color: hsl(0, 100.00%, 91.60%); opacity: 0.82" title="-0.094">بي</span><span style="background-color: hsl(120, 100.00%, 63.67%); opacity: 0.97" title="0.765"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.878">😂</span></p>
# ----------------------------------------------------------------------------------------------------
